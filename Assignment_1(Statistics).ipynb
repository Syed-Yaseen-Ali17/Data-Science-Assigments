# %%
import pandas as pd
df = pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
# Mean, Median, Mode & Std of Volume
print("Mean of Volume: ", df['Volume'].mean())
print("Median of Volume: ",df['Volume'].median())
print("Mode of Volume: ",df['Volume'].mode())
print("Std of Volume: ",df['Volume'].std())
# Out:
# Mean of Volume:  5.066666666666666
# Median of Volume:  4.0
# Mode of Volume:  0    3
# Name: Volume, dtype: int64
# Std of Volume:  4.231602391213923

# %%
# Mean, Median, Mode & Std of Avg Price
print("Mean of Avg Price: ", df['Avg Price'].mean())
print("Median of Avg Price: ",df['Avg Price'].median())
print("Mode of Avg Price: ",df['Avg Price'].mode())
print("Std of Avg Price: ",df['Avg Price'].std())
# Out:
# Mean of Avg Price:  10453.433333333332
# Median of Avg Price:  1450.0
# Mode of Avg Price:  0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64
# Std of Avg Price:  18079.90483993647

# %%
# Mean, Median, Mode & Std of Total Sales Value
print("Mean of Total Sales Value: ", df['Total Sales Value'].mean())
print("Median of Total Sales Value: ",df['Total Sales Value'].median())
print("Mode of Total Sales Value: ",df['Total Sales Value'].mode())
print("Std of Total Sales Value: ",df['Total Sales Value'].std())
# Out:
# Mean of Total Sales Value:  33812.83555555555
# Median of Total Sales Value:  5700.0
# Mode of Total Sales Value:  0    24300
# Name: Total Sales Value, dtype: int64
# Std of Total Sales Value:  50535.07417255325

# %%
# Mean, Median, Mode & Std of Discount Rate (%)
print("Mean of Discount Rate (%): ", df['Discount Rate (%)'].mean())
print("Median of Discount Rate (%): ",df['Discount Rate (%)'].median())
print("Mode of Discount Rate (%): ",df['Discount Rate (%)'].mode())
print("Std of Discount Rate (%): ",df['Discount Rate (%)'].std())
# Out:
# Mean of Discount Rate (%):  15.155241895330914
# Median of Discount Rate (%):  16.57776564929597
# Mode of Discount Rate (%):  0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64
# Std of Discount Rate (%):  4.22060215332551

# %%
# Mean, Median, Mode & Std of Discount Amount
print("Mean of Discount Amount: ", df['Discount Amount'].mean())
print("Median of Discount Amount: ",df['Discount Amount'].median())
print("Mode of Discount Amount: ",df['Discount Amount'].mode())
print("Std of Discount Amount: ",df['Discount Amount'].std())
# Out:
# Mean of Discount Amount:  3346.499424342415
# Median of Discount Amount:  988.9337332382784
# Mode of Discount Amount:  0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64
# Std of Discount Amount:  4509.902963353998

# %%
# Mean, Median, Mode & Std of Net Sales Value
print("Mean of Net Sales Value: ", df['Net Sales Value'].mean())
print("Median of Net Sales Value: ",df['Net Sales Value'].median())
print("Mode of Net Sales Value: ",df['Net Sales Value'].mode())
print("Std of Net Sales Value: ",df['Net Sales Value'].std())
# Out:
# Mean of Net Sales Value:  30466.336131270138
# Median of Net Sales Value:  4677.788059301853
# Mode of Net Sales Value:  0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64
# Std of Net Sales Value:  46358.65662406695

# %%
#By looking at the mean, median, mode, and standard deviation of different columns we can get a good understanding of the central tendency and spread of the data. For example, if the mean and median of 'Volume' are close together, it suggests that the distribution of sales volume is roughly symmetrical. A high standard deviation would indicate a wide spread of sales volumes, while a low standard deviation would indicate that sales volumes are clustered around the mean. 

#Similarly, the mode tells us the most frequent values in each column, which can be useful for identifying common price points, discount rates, etc. 

#By comparing these statistics across different columns, we can start to understand the relationships between different variables in the dataset. For example, we might notice that higher discount rates tend to be associated with lower net sales values, or that there's a particular average price point that corresponds to the highest sales volumes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Histogram of Volume
plt.figure(figsize=(10,6))
plt.hist(df['Volume'], bins=15, edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')

# To find Presence of Outliers
mean = np.mean(df["Volume"])
std_dev = np.std(df['Volume'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Volume'].skew()
# Out:
# 2.731723626557714

# %%
# Histogram of Avg Price
plt.figure(figsize=(10,6))
plt.hist(df['Avg Price'], bins=15, edgecolor='black')
plt.title('Histogram of Avg Price')
plt.xlabel('Avg Price')
plt.ylabel('Frequency')

# To find Presence of Outliers
mean = np.mean(df['Avg Price'])
std_dev = np.std(df['Avg Price'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Avg Price'].skew()
# Out:
# 1.9088730767759727

# %%
# Histogram of Total Sales Value
plt.figure(figsize=(10,6))
plt.hist(df['Total Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Total Sales Value')
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')

# To find Presence of Outliers
mean = np.mean(df['Total Sales Value'])
std_dev = np.std(df['Total Sales Value'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Total Sales Value'].skew()
# Out:
# 1.5347293238977937

# %%
# Histogram of Discount Rate (%)
plt.figure(figsize=(10,6))
plt.hist(df['Discount Rate (%)'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Rate (%)')
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')

# To find Presence of Outliers
mean = np.mean(df['Discount Rate (%)'])
std_dev = np.std(df['Discount Rate (%)'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Discount Rate (%)'].skew()
# Out:
# -1.0622943696988825

# %%
# Histogram of Discount Amount
plt.figure(figsize=(10,6))
plt.hist(df['Discount Amount'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Amount')
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')

# To find Presence of Outliers
mean = np.mean(df['Discount Amount'])
std_dev = np.std(df['Discount Amount'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Discount Amount'].skew()
# Out:
# 1.9130377339538271

# %%
# Histogram of Net Sales Value
plt.figure(figsize=(10,6))
plt.hist(df['Net Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Net Sales Value')
plt.xlabel('Discount Amount')
plt.ylabel('Net Sales Value')

# To find Presence of Outliers
mean = np.mean(df['Net Sales Value'])
std_dev = np.std(df['Net Sales Value'])
plt.axvline(mean + 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std_dev, color='r', linestyle='dashed', linewidth=1)
plt.show()

# Skewness
df['Net Sales Value'].skew()
# Out:
# 1.5408217575344376

# %%
# Inference from Skewness:
# -Positive skewness in 'Volume', 'Total Sales Value', 'Discount Amount', and 'Net Sales Value' suggests a longer tail on the right side, indicating some larger values are pulling the mean higher than the median.
# -Slight positive skewness in 'Avg Price' indicates a tendency towards higher prices, but the distribution is relatively symmetrical.
# -Negative skewness in 'Discount Rate (%)' suggests a tail on the left, implying a few lower discount rates are influencing the distribution.

# Outliers:
# -Potential outliers are observed in 'Volume', 'Total Sales Value', and 'Discount Amount' based on the 3-sigma rule.
# -No significant outliers are detected in 'Avg Price', 'Discount Rate (%)', and 'Net Sales Value'.

# %%
# Boxplot for all numerical Columns

# Boxplot for 'Volume'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Volume'])
plt.title('Boxplot of Volume')
plt.show()

# %%
# Boxplot for 'Avg Price'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Avg Price'])
plt.title('Boxplot of Avg Price')
plt.show()

# %%
# Boxplot for 'Total Sales Value'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Total Sales Value'])
plt.title('Boxplot of Total Sales Value')
plt.show()

# %%
# Boxplot for 'Discount Rate (%)'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Discount Rate (%)'])
plt.title('Boxplot of Discount Rate (%)')
plt.show()

# %%
# Boxplot for 'Discount Amount'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Discount Amount'])
plt.title('Boxplot of Discount Amount')
plt.show()

# %%
# Boxplot for 'Net Sales Value'
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['Net Sales Value'])
plt.title('Boxplot of Net Sales Value')
plt.show()

# %%
# Identifying Outliers
import numpy as np

numerical_cols = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
z_scores = np.abs((df[numerical_cols] - df[numerical_cols].mean()) / df[numerical_cols].std())

outliers = (z_scores > 3).any(axis=1)

print(df[outliers])
# Out:
#            Date        Day  SKU City  Volume       BU    Brand        Model  \
# 0    01-04-2021   Thursday  M01    C      15  Mobiles    RealU        RU-10
# 9    01-04-2021   Thursday  M10    C       3  Mobiles   Orange         O-11
# 30   02-04-2021     Friday  M01    C      11  Mobiles    RealU        RU-10
# 40   02-04-2021     Friday  F01    C      29     FMCG   Babaji  Babaji Oil
# 66   03-04-2021   Saturday  M07    C       4  Mobiles  Sumsang         S-20
# 70   03-04-2021   Saturday  F01    C      24     FMCG   Babaji  Babaji Oil
# 100  04-04-2021     Sunday  F01    C      25     FMCG   Babaji  Babaji Oil
# 180  07-04-2021  Wednesday  M01    C      12  Mobiles    RealU        RU-10
# 189  07-04-2021  Wednesday  M10    C       3  Mobiles   Orange         O-11
# 190  07-04-2021  Wednesday  F01    C      22     FMCG   Babaji  Babaji Oil
# 210  08-04-2021   Thursday  M01    C      14  Mobiles    RealU        RU-10
# ...

# %%
# Calculate IQR for all numerical columns
numerical_cols = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

for col in numerical_cols:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  print(f"IQR for {col}: {IQR}")
# Out:
# IQR for Volume: 3.0
# IQR for Avg Price: 9635.0
# IQR for Total Sales Value: 50500.0
# IQR for Discount Rate (%): 4.149655934050962
# IQR for Discount Amount: 4856.03612280112
# IQR for Net Sales Value: 45645.70420627015

# %%
# Bar charts of categorical columns
plt.figure(figsize=(10, 6))
for column in df.columns:
  if df[column].dtype == object:
     df[column].value_counts().plot(kind='bar')
     plt.title(f'Bar Chart of {column}')
     plt.xlabel(f'{column}')
     plt.ylabel('Count')
     plt.show()

# %%
# Standardization
X_cont = df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']]

from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X_cont_SS = SS.fit_transform(X_cont)
X_cont_SS = pd.DataFrame(X_cont_SS)
X_cont_SS.columns = list(X_cont)
X_cont_SS.head()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.350029   0.091173           2.925721          -0.830289         3.952816
# 1  1.167129  -0.019570           1.330995          -0.852661         1.849014
# 2  0.457388   0.312659           1.562775          -1.351631         1.622995
# 3  0.220808   0.534146           1.719276          -1.949723         1.113807
# 4 -0.488932  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value
# 0         2.804756
# 1         1.271026
# 2         1.545675
# 3         1.765810
# 4        -0.227595

# %%
# Before and after comparisons of the data distributions

# Volume
# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Volume'], bins=15, edgecolor='black')
plt.title('Histogram of Volume (Before Standardization)')
plt.xlabel('Volume')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Volume'], bins=15, edgecolor='black')
plt.title('Histogram of Volume (After Standardization)')
plt.xlabel('Volume (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Avg Price

# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Avg Price'], bins=15, edgecolor='black')
plt.title('Histogram of Avg Price (Before Standardization)')
plt.xlabel('Avg Price')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Avg Price'], bins=15, edgecolor='black')
plt.title('Histogram of Avg Price (After Standardization)')
plt.xlabel('Avg Price (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Total Sales Value

# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Total Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Total Sales Value (Before Standardization)')
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Total Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Total Sales Value (After Standardization)')
plt.xlabel('Total Sales Value (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Discount Rate (%)

# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Discount Rate (%)'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Rate (%) (Before Standardization)')
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Discount Rate (%)'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Rate (%) (After Standardization)')
plt.xlabel('Discount Rate (%) (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Discount Amount

# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Discount Amount'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Amount (Before Standardization)')
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Discount Amount'], bins=15, edgecolor='black')
plt.title('Histogram of Discount Amount (After Standardization)')
plt.xlabel('Discount Amount (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Net Sales Value

# Before Standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Net Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Net Sales Value (Before Standardization)')
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')

# After Standardization
plt.subplot(1, 2, 2)
plt.hist(X_cont_SS['Net Sales Value'], bins=15, edgecolor='black')
plt.title('Histogram of Net Sales Value (After Standardization)')
plt.xlabel('Net Sales Value (Standardized)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#One-hot encoding
categorical_cols = df.select_dtypes(include=['object']).columns

df_encoded = pd.get_dummies(df, columns=categorical_cols)

print(df_encoded.head())
# Out:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0    160346.501180             True            False            False
# 1     89323.897039             True            False            False
# 2    102042.089843             True            False            False
# 3    112235.925298             True            False            False
# 4     19927.053770             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %%
# CONCLUSION:

#Key Findings:
#- Outliers present in 'Volume', 'Total Sales Value', 'Discount Amount', and 'Net Sales Value'. Further investigation needed.
#- Positive skewness observed in 'Volume', 'Total Sales Value', 'Discount Amount', and 'Net Sales Value', suggesting a few large values.
#- Standardization applied to numerical features to improve model performance.

# %%
# Reflecting on the importance of data preprocessing steps:

# Standardization:
# - Brings numerical features to a common scale (mean of 0, standard deviation of 1).
# - Helps algorithms that are sensitive to feature scales (e.g., distance-based algorithms like k-NN, k-means, SVM).
# - Prevents features with larger ranges from dominating the learning process.

# One-Hot Encoding:
# - Converts categorical data into a numerical format suitable for machine learning algorithms.
# - Enhances model interpretability by providing clear insights into the influence of different categories.

# Overall Impact:
# - Data preprocessing steps like standardization and one-hot encoding are crucial for:
#     - Improving model performance and accuracy.
#     - Ensuring fair and unbiased learning from all features.
#     - Enhancing model interpretability and understanding.
# - These steps are essential for building robust and reliable machine learning models.
