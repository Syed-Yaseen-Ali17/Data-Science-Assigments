# %%
# 1. Exploratory Data Analysis (EDA):
import pandas as pd 
titanic_train = pd.read_csv('Titanic_train.csv')
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_test = pd.read_csv('Titanic_test.csv')
titanic_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Combine train and test datasets for EDA
df = pd.concat([titanic_train, titanic_test], ignore_index=True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Check for missing values in each column
print(df.isnull().sum())
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# Explore data distributions using histograms and box plots
import matplotlib.pyplot as plt
# Histograms for numerical features
df.hist(figsize=(12, 8))
plt.show()

# Box plots for numerical features
df.boxplot(figsize=(12, 8))
plt.show()

# %%
# Visualize relationships between features and survival using scatter plots and bar plots
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot for Age vs. Fare, colored by survival
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=titanic_train)
plt.title('Age vs. Fare by Survival')
plt.show()

# Bar plot for survival rate by passenger class
plt.figure(figsize=(8, 6))
sns.barplot(x='Pclass', y='Survived', data=titanic_train)
plt.title('Survival Rate by Passenger Class')
plt.show()

# Bar plot for survival rate by sex
plt.figure(figsize=(8, 6))
sns.barplot(x='Sex', y='Survived', data=titanic_train)
plt.title('Survival Rate by Sex')
plt.show()

# %%
# 2. Data Preprocessing:
# Impute missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Fare'] = df['Fare'].fillna(df['Fare'].median())

# %%
# Encode categorical variables:
# Label encoding
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
X_cate = df[['Survived','Name','Sex','Ticket','Cabin','Embarked']]

X_cate['Survived']=LE.fit_transform(X_cate['Survived'])
X_cate['Name']=LE.fit_transform(X_cate['Name'])
X_cate['Sex']=LE.fit_transform(X_cate['Sex'])
X_cate['Ticket']=LE.fit_transform(X_cate['Ticket'])
X_cate['Cabin']=LE.fit_transform(X_cate['Cabin'])
X_cate['Embarked']=LE.fit_transform(X_cate['Embarked'])

X_cate.head()
# Out:
# C:\Users\Syed Yaseen Ali\AppData\Local\Temp\ipykernel_32772\1482354945.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_cate['Survived']=LE.fit_transform(X_cate['Survived'])
# C:\Users\Syed Yaseen Ali\AppData\Local\Temp\ipykernel_32772\1482354945.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_cate['Name']=LE.fit_transform(X_cate['Name'])
# C:\Users\Syed Yaseen Ali\AppData\Local\Temp\ipykernel_32772\1482354945.py:9: SettingWithCopyWarning:
# ...

# %%
# Standard scaling
X_cont = titanic_train[['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]

#Standardization
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X_cont_SS = SS.fit_transform(X_cont)
X_cont_SS = pd.DataFrame(X_cont_SS)
X_cont_SS.columns = list(X_cont)
X_cont_SS.head()
# Out:
#    PassengerId    Pclass       Age     SibSp     Parch      Fare
# 0    -1.730108  0.827377 -0.530377  0.432793 -0.473674 -0.502445
# 1    -1.726220 -1.566107  0.571831  0.432793 -0.473674  0.786845
# 2    -1.722332  0.827377 -0.254825 -0.474545 -0.473674 -0.488854
# 3    -1.718444 -1.566107  0.365167  0.432793 -0.473674  0.420730
# 4    -1.714556  0.827377  0.365167 -0.474545 -0.473674 -0.486337

# %%
# !pip install lightgbm

# %%
# 3. Building Predictive Models:
# Prepare the features and target variable
X = pd.concat([X_cont_SS, X_cate], axis=1)
print(X.shape)

y = X['Survived']
print(y.shape)
# Out:
# (1309, 12)
# (1309,)

# %%
X
# Out:
#       PassengerId    Pclass       Age     SibSp     Parch      Fare  Survived  \
# 0       -1.730108  0.827377 -0.530377  0.432793 -0.473674 -0.502445         0
# 1       -1.726220 -1.566107  0.571831  0.432793 -0.473674  0.786845         1
# 2       -1.722332  0.827377 -0.254825 -0.474545 -0.473674 -0.488854         1
# 3       -1.718444 -1.566107  0.365167  0.432793 -0.473674  0.420730         1
# 4       -1.714556  0.827377  0.365167 -0.474545 -0.473674 -0.486337         0
# ...           ...       ...       ...       ...       ...       ...       ...
# 1304          NaN       NaN       NaN       NaN       NaN       NaN         2
# 1305          NaN       NaN       NaN       NaN       NaN       NaN         2
# 1306          NaN       NaN       NaN       NaN       NaN       NaN         2
# 1307          NaN       NaN       NaN       NaN       NaN       NaN         2
# 1308          NaN       NaN       NaN       NaN       NaN       NaN         2
#
# ...

# %%
# Implement a light gradient boosting model
import lightgbm as lgb

# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Create LightGBM dataset
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)

# Set hyperparameters
params = {
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# Train the LightGBM model
num_boost_round = 10  # Number of boosting rounds 

model = lgb.train(
    params,
    train_data,
    num_boost_round=num_boost_round,
    valid_sets=[test_data],
)

# Make predictions on the testing set
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# [LightGBM] [Info] Number of positive: 550, number of negative: 366
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 971
# [LightGBM] [Info] Number of data points in the train set: 916, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.600437 -> initscore=0.407285
# [LightGBM] [Info] Start training from score 0.407285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Convert probabilities to binary predictions (0 or 1)
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Evaluate the model's performance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary, average='weighted')
recall = recall_score(y_test, y_pred_binary, average='weighted')
f1 = f1_score(y_test, y_pred_binary, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.7251908396946565
# Precision: 0.5917121046892039
# Recall: 0.7251908396946565
# F1-score: 0.6353493834409865
# C:\Users\Syed Yaseen Ali\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# !pip install xgboost

# %%
# Implement a xtreme gradient boosting model
import xgboost as xgb

# Create DMatrix for XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Set hyperparameters
param = {
    'objective': 'multi:softmax',  # For multiclass classification
    'num_class': 3,                # Number of classes in the dataset
    'eval_metric': 'auc',          # Evaluation metric
    'max_depth': 3,                # Maximum depth of trees
    'learning_rate': 0.1,          # Learning rate
}

# Train the XGBoost model
num_round = 100  # Number of boosting rounds
model_xgb = xgb.train(param, dtrain, num_round)

# Make predictions on the testing set
y_pred_xgb = model_xgb.predict(dtest)

# Convert probabilities to binary predictions (0 or 1)
y_pred_binary_xgb = [1 if p >= 0.5 else 0 for p in y_pred]

# Evaluate the model's performance
accuracy_xgb = accuracy_score(y_test, y_pred_binary_xgb)
precision_xgb = precision_score(y_test, y_pred_binary_xgb, average='weighted')
recall_xgb = recall_score(y_test, y_pred_binary_xgb, average='weighted')
f1_xgb = f1_score(y_test, y_pred_binary_xgb, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6412213740458015
# Precision: 0.496797774615086
# Recall: 0.6412213740458015
# F1-score: 0.5382486566269229
# C:\Users\Syed Yaseen Ali\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Use techniques like cross-validation and hyperparameter tuning to optimize model performance.

# Cross-validation and Hyperparameter Tuning for LightGBM:
import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter distribution for hyperparameter tuning
param_dist = {
    'num_leaves': [20, 31, 50],
    'learning_rate': [0.01, 0.05, 0.1],
    'feature_fraction': [0.8, 0.9, 1.0],
    'bagging_fraction': [0.8, 0.9, 1.0],
    'bagging_freq': [5, 10]
}

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=lgb.LGBMClassifier(), param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy')

# Fit the random search to the data
random_search.fit(X, y)

# Get the best hyperparameters
best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_model = random_search.best_estimator_

# Make predictions on the testing set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the best model's performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Best Model Performance:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000530 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1033
# ...

# %%
# Cross-validation and Hyperparameter Tuning for XGBoost:
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.3]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=xgb.XGBClassifier(), param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the data
grid_search.fit(X, y)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_

# Make predictions on the testing set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the best model's performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Best Model Performance:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# Best Model Performance:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0

# %%
# 4. Comparative Analysis:
# Visualize and interpret the results to identify the strengths and weaknesses of each algorithm.
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame for easy plotting
metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1-score'],
    'LightGBM': [accuracy, precision, recall, f1],
    'XGBoost': [accuracy_xgb, precision_xgb, recall_xgb, f1_xgb]
})

# Melt the DataFrame for plotting
metrics_melted = pd.melt(metrics_df, id_vars='Metric', var_name='Model', value_name='Score')

# Plot the comparison using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Score', hue='Model', data=metrics_melted)
plt.title('Performance Comparison: LightGBM vs. XGBoost') 
plt.ylabel('Score')
plt.show()

# %%
# Interpretation:
# - In this scenario, LightGBM achieves a higher accuracy (0.72 vs 0.64) and recall (0.72 vs. 0.64) compared to XGBoost. 
# - This indicates that LightGBM is better at correctly identifying positive instances (e.g., passengers who survived) and capturing a larger proportion of true positives. 

# - Also, LGBoost demonstrates a higher precision (0.59 vs 0.49) than XGBM. 
# - This suggests that LGBoost is more effective at minimizing false positives, meaning it is less likely to incorrectly predict a passenger as surviving when they did not.

# - The F1-score, which balances precision and recall, is slightly higher for LightGBM (0.63 vs 0.53). 
# - This indicates a slightly better overall performance for LightGBM in this specific context.

# Conclusion:
# - Based on these results, if the goal is to maximize the identification of true positive instances (survivors) even at the cost of some false positives, LightGBM might be preferred. 
# - If minimizing false positives is a higher priority, XGBoost could be a better choice. 
# - Ultimately, the choice between LightGBM and XGBoost depends on the specific requirements of the problem and the relative importance of different performance metrics.
